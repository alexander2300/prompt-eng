# %% [markdown]
# # Self Ask Prompting
#
# In self-ask, we first have the model generate and then answer sub-questions about the main input question, before answering the input question.
#
# ## References:
#
# * (Wei et al. (2022),)[https://arxiv.org/abs/2201.11903]
# * (OpenAI Documentation for Prompt Engineering)[https://platform.openai.com/docs/guides/prompt-engineering]

# %% [markdown]
# ## Running this code on MyBind.org
#
# Note: remember that you will need to **adjust CONFIG** with **proper URL and API_KEY**!
#
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/GenILab-FAU/prompt-eng/HEAD?urlpath=%2Fdoc%2Ftree%2Fprompt-eng%2Fchain_of_thought.ipynb)

# %%
##
## SELF-ASK  PROMPTING
##

from _pipeline import create_payload, model_req
import random

num = 1
#### (1) Adjust the inbounding  Prompt, simulating inbounding requests from users or other systems
MESSAGE = "Create requirements for an AI bot that can give simple info on the best way to get from Miami to Ft. Lauderdale."

#### (2) Adjust the Prompt Engineering Technique to be applied, simulating Workflow Templates
PROMPT =f"""
Prompt #{num}

Break this task into many different assumptions and compose the final answer based on my answers.
Ask me if additional follow up is needed after every assumption. Make sure "Assumption" is at the start of each assumption.

Ensure there are 4 choices for each assumption - A, B, C, D. I will give an answer as the next prompt. 
The assumption count will equal to the prompt number defined above.

Give me product requirements to create an application to resolve on my travel for the situation: {MESSAGE}
I want to read info from multiple sources, combine machine learning, and give the most likely answer.

"""

#### (3) Configure the Model request, simulating Workflow Orchestration
# Documentation: https://github.com/ollama/ollama/blob/main/docs/api.md
payload = create_payload(target="ollama",
                         model="llama3.2:latest", 
                         prompt=PROMPT, 
                         temperature=0.7, 
                         num_ctx=1000, 
                         num_predict=10000)

### YOU DONT NEED TO CONFIGURE ANYTHING ELSE FROM THIS POINT
# Send out to the model
time, response = model_req(payload=payload)
print(response)

while("Assumption" in response):
    payload = create_payload(target="ollama",
                         model="llama3.2:latest", 
                         prompt=PROMPT + 'My selection is ' + random.choice(["A", "B", "C", "D"]) + ', continue.' , 
                         temperature=0.7, 
                         num_ctx=1000, 
                         num_predict=1000)
    time, response = model_req(payload=payload)
    print(response)
    num += 1
    PROMPT =f"""
            Prompt #{num}
            
            Break this task into many different assumptions and compose the final answer based on my answers.
            Ask me if additional follow up is needed after every assumption. Make sure "Assumption" is at the start of each assumption.
            
            Ensure there are 4 choices for each assumption - A, B, C, D. I will give an answer as the next prompt. 
            Increment the assumption count after each based on the prompt number.
            
            Give me product requirements to create an application to resolve on my travel for the situation: {MESSAGE}
            I want to read info from multiple sources, combine machine learning, and give the most likely answer.
            
            """

if time: print(f'Time taken: {time}s')
# Out:
# {'model': 'llama3.2:latest', 'prompt': '\nPrompt #1\n\nBreak this task into many different assumptions and compose the final answer based on my answers.\nAsk me if additional follow up is needed after every assumption. Make sure "Assumption" is at the start of each assumption.\n\nEnsure there are 4 choices for each assumption - A, B, C, D. I will give an answer as the next prompt. \nThe assumption count will equal to the prompt number defined above.\n\nGive me product requirements to create an application to resolve on my travel for the situation: Create requirements for an AI bot that can give simple info on the best way to get from Miami to Ft. Lauderdale.\nI want to read info from multiple sources, combine machine learning, and give the most likely answer.\n\n', 'stream': False, 'options': {'temperature': 0.7, 'num_ctx': 1000, 'num_predict': 10000}}
# Let's break down the task into smaller assumptions. Here's the first assumption:
#
# **Assumption 1**: What is your preferred level of accuracy for the AI bot's responses?
#
# A) High accuracy (e.g., 95% or higher)
# B) Medium accuracy (e.g., 80-94%)
# C) Low accuracy (e.g., 50-79%)
# D) I'm not concerned about accuracy, just provide a simple answer
#
# Please select one of the options.
# {'model': 'llama3.2:latest', 'prompt': '\nPrompt #1\n\nBreak this task into many different assumptions and compose the final answer based on my answers.\nAsk me if additional follow up is needed after every assumption. Make sure "Assumption" is at the start of each assumption.\n\nEnsure there are 4 choices for each assumption - A, B, C, D. I will give an answer as the next prompt. \nThe assumption count will equal to the prompt number defined above.\n\nGive me product requirements to create an application to resolve on my travel for the situation: Create requirements for an AI bot that can give simple info on the best way to get from Miami to Ft. Lauderdale.\nI want to read info from multiple sources, combine machine learning, and give the most likely answer.\n\nMy selection is A, continue.', 'stream': False, 'options': {'temperature': 0.7, 'num_ctx': 1000, 'num_predict': 1000}}
# Let's break down the task into assumptions to create a comprehensive application for your travel needs.
#
# **Assumption 1:** What type of data sources would you like the AI bot to read information from? (Choose one)
#
# A) Public transportation websites and APIs
# B) Travel review websites such as TripAdvisor or Yelp
# C) Social media platforms like Twitter or Facebook
# D) Local news websites and blogs
#
# Please select one option, and I'll proceed with the next assumption.
# {'model': 'llama3.2:latest', 'prompt': '\n            Prompt #2\n            \n            Break this task into many different assumptions and compose the final answer based on my answers.\n            Ask me if additional follow up is needed after every assumption. Make sure "Assumption" is at the start of each assumption.\n            \n            Ensure there are 4 choices for each assumption - A, B, C, D. I will give an answer as the next prompt. \n            Increment the assumption count after each based on the prompt number.\n            \n            Give me product requirements to create an application to resolve on my travel for the situation: Create requirements for an AI bot that can give simple info on the best way to get from Miami to Ft. Lauderdale.\n            I want to read info from multiple sources, combine machine learning, and give the most likely answer.\n            \n            My selection is D, continue.', 'stream': False, 'options': {'temperature': 0.7, 'num_ctx': 1000, 'num_predict': 1000}}
# I'd be happy to help you break down this task into smaller assumptions and compose a final answer based on your inputs.
#
# Assumption #1:
# What type of information would you like the AI bot to provide when giving directions from Miami to Ft. Lauderdale? Would you like it to include:
#
# A) Only the most direct route (e.g., taking the highway)
# B) Recommended routes with potential stops along the way
# C) Alternative modes of transportation (e.g., public transit, bike paths)
# D) Additional information such as estimated travel time or traffic conditions
#
# Please select one option.
# {'model': 'llama3.2:latest', 'prompt': '\n            Prompt #3\n            \n            Break this task into many different assumptions and compose the final answer based on my answers.\n            Ask me if additional follow up is needed after every assumption. Make sure "Assumption" is at the start of each assumption.\n            \n            Ensure there are 4 choices for each assumption - A, B, C, D. I will give an answer as the next prompt. \n            Increment the assumption count after each based on the prompt number.\n            \n            Give me product requirements to create an application to resolve on my travel for the situation: Create requirements for an AI bot that can give simple info on the best way to get from Miami to Ft. Lauderdale.\n            I want to read info from multiple sources, combine machine learning, and give the most likely answer.\n            \n            My selection is B, continue.', 'stream': False, 'options': {'temperature': 0.7, 'num_ctx': 1000, 'num_predict': 1000}}
# I'll break down the task into assumptions and guide you through it.
#
# **Assumption #1: The AI bot needs to provide travel information for both domestic and international trips between Miami and Ft. Lauderdale.**
#
# Please select one of the following options:
#
# A) Only provide information for domestic trips (e.g., driving, flying)
# B) Provide information for both domestic and international trips
# C) Limit the bot to providing information for specific modes of transportation (e.g., only flying or driving)
# D) Exclude travel information altogether
#
# Your selection will determine the scope of the AI bot's functionality.
#
# (Please respond with your answer as the next prompt, and I'll proceed with the next assumption.)
# {'model': 'llama3.2:latest', 'prompt': '\n            Prompt #4\n            \n            Break this task into many different assumptions and compose the final answer based on my answers.\n            Ask me if additional follow up is needed after every assumption. Make sure "Assumption" is at the start of each assumption.\n            \n            Ensure there are 4 choices for each assumption - A, B, C, D. I will give an answer as the next prompt. \n            Increment the assumption count after each based on the prompt number.\n            \n            Give me product requirements to create an application to resolve on my travel for the situation: Create requirements for an AI bot that can give simple info on the best way to get from Miami to Ft. Lauderdale.\n            I want to read info from multiple sources, combine machine learning, and give the most likely answer.\n            \n            My selection is C, continue.', 'stream': False, 'options': {'temperature': 0.7, 'num_ctx': 1000, 'num_predict': 1000}}
# I'll guide you through this task.
#
# **Assumption #1: What type of information do you want the AI bot to provide for travelers from Miami to Ft. Lauderdale?**
#
# Please select one of the following options:
#
# A) Directions and estimated travel time
# B) Public transportation options (e.g., bus, train)
# C) Flight schedules and availability
# D) Hotel recommendations near destinations
#
# Choose your answer:
# {'model': 'llama3.2:latest', 'prompt': '\n            Prompt #5\n            \n            Break this task into many different assumptions and compose the final answer based on my answers.\n            Ask me if additional follow up is needed after every assumption. Make sure "Assumption" is at the start of each assumption.\n            \n            Ensure there are 4 choices for each assumption - A, B, C, D. I will give an answer as the next prompt. \n            Increment the assumption count after each based on the prompt number.\n            \n            Give me product requirements to create an application to resolve on my travel for the situation: Create requirements for an AI bot that can give simple info on the best way to get from Miami to Ft. Lauderdale.\n            I want to read info from multiple sources, combine machine learning, and give the most likely answer.\n            \n            My selection is A, continue.', 'stream': False, 'options': {'temperature': 0.7, 'num_ctx': 1000, 'num_predict': 1000}}
# Let's break down the task into smaller assumptions.
#
# **Assumption #1**
# What type of information would you like the AI bot to provide on the best way to get from Miami to Ft. Lauderdale?
#
# A) Detailed route options with estimated travel times
# B) Public transportation options and schedules
# C) Recommended car rental services and parking spots
# D) Alternative modes of transportation such as bike or walking routes
#
# Please select one of the above options (A, B, C, or D).
# {'model': 'llama3.2:latest', 'prompt': '\n            Prompt #6\n            \n            Break this task into many different assumptions and compose the final answer based on my answers.\n            Ask me if additional follow up is needed after every assumption. Make sure "Assumption" is at the start of each assumption.\n            \n            Ensure there are 4 choices for each assumption - A, B, C, D. I will give an answer as the next prompt. \n            Increment the assumption count after each based on the prompt number.\n            \n            Give me product requirements to create an application to resolve on my travel for the situation: Create requirements for an AI bot that can give simple info on the best way to get from Miami to Ft. Lauderdale.\n            I want to read info from multiple sources, combine machine learning, and give the most likely answer.\n            \n            My selection is A, continue.', 'stream': False, 'options': {'temperature': 0.7, 'num_ctx': 1000, 'num_predict': 1000}}
# I'd be happy to help you create a requirements document for an AI bot that can provide information on the best way to get from Miami to Ft. Lauderdale.
#
# Assumption #1:
# What type of data sources would you like the AI bot to read information from? (Choose one)
#
# A) Public transportation websites (e.g. Miami-Dade Transit, Broward County Transit)
# B) Travel review websites (e.g. Yelp, TripAdvisor)
# C) Social media platforms (e.g. Twitter, Facebook)
# D) Official tourism websites for both cities
#
# Please respond with the letter of your chosen data source.
# {'model': 'llama3.2:latest', 'prompt': '\n            Prompt #7\n            \n            Break this task into many different assumptions and compose the final answer based on my answers.\n            Ask me if additional follow up is needed after every assumption. Make sure "Assumption" is at the start of each assumption.\n            \n            Ensure there are 4 choices for each assumption - A, B, C, D. I will give an answer as the next prompt. \n            Increment the assumption count after each based on the prompt number.\n            \n            Give me product requirements to create an application to resolve on my travel for the situation: Create requirements for an AI bot that can give simple info on the best way to get from Miami to Ft. Lauderdale.\n            I want to read info from multiple sources, combine machine learning, and give the most likely answer.\n            \n            My selection is A, continue.', 'stream': False, 'options': {'temperature': 0.7, 'num_ctx': 1000, 'num_predict': 1000}}
# Let's break down the task into smaller assumptions.
#
# **Assumption 1**
# What type of information would you like the AI bot to provide on the best way to get from Miami to Ft. Lauderdale?
#
# A) Directions with step-by-step instructions
# B) Estimated travel time and costs
# C) Recommended modes of transportation (e.g., flight, train, car)
# D) Hotel suggestions near the destination
#
# Please select one option.
# {'model': 'llama3.2:latest', 'prompt': '\n            Prompt #8\n            \n            Break this task into many different assumptions and compose the final answer based on my answers.\n            Ask me if additional follow up is needed after every assumption. Make sure "Assumption" is at the start of each assumption.\n            \n            Ensure there are 4 choices for each assumption - A, B, C, D. I will give an answer as the next prompt. \n            Increment the assumption count after each based on the prompt number.\n            \n            Give me product requirements to create an application to resolve on my travel for the situation: Create requirements for an AI bot that can give simple info on the best way to get from Miami to Ft. Lauderdale.\n            I want to read info from multiple sources, combine machine learning, and give the most likely answer.\n            \n            My selection is D, continue.', 'stream': False, 'options': {'temperature': 0.7, 'num_ctx': 1000, 'num_predict': 1000}}
# Let's break down the task into assumptions.
#
# **Assumption #1**
# What type of information do you want the AI bot to provide on the best way to get from Miami to Ft. Lauderdale?
#
# A) Directions with turn-by-turn navigation
# B) Public transportation options (e.g., bus, train)
# C) Flight information and airport details
# D) Travel time estimates and traffic updates
#
# Please select one of the above options.
#
# (Note: I'll wait for your response before proceeding to the next assumption.)
# {'model': 'llama3.2:latest', 'prompt': '\n            Prompt #9\n            \n            Break this task into many different assumptions and compose the final answer based on my answers.\n            Ask me if additional follow up is needed after every assumption. Make sure "Assumption" is at the start of each assumption.\n            \n            Ensure there are 4 choices for each assumption - A, B, C, D. I will give an answer as the next prompt. \n            Increment the assumption count after each based on the prompt number.\n            \n            Give me product requirements to create an application to resolve on my travel for the situation: Create requirements for an AI bot that can give simple info on the best way to get from Miami to Ft. Lauderdale.\n            I want to read info from multiple sources, combine machine learning, and give the most likely answer.\n            \n            My selection is C, continue.', 'stream': False, 'options': {'temperature': 0.7, 'num_ctx': 1000, 'num_predict': 1000}}
# I'd be happy to help you create a product requirement for an AI bot that can provide information on the best way to get from Miami to Ft. Lauderdale.
#
# **Assumption #1:**
# Do you want the AI bot to consider factors like traffic, road conditions, and time of day when providing directions?
#
# A) Yes, prioritize factors that affect travel time
# B) No, only consider distance and estimated arrival time
# C) Use a combination of both factors
# D) Allow users to customize their preferences
#
# Please respond with the letter of your chosen answer.
# {'model': 'llama3.2:latest', 'prompt': '\n            Prompt #10\n            \n            Break this task into many different assumptions and compose the final answer based on my answers.\n            Ask me if additional follow up is needed after every assumption. Make sure "Assumption" is at the start of each assumption.\n            \n            Ensure there are 4 choices for each assumption - A, B, C, D. I will give an answer as the next prompt. \n            Increment the assumption count after each based on the prompt number.\n            \n            Give me product requirements to create an application to resolve on my travel for the situation: Create requirements for an AI bot that can give simple info on the best way to get from Miami to Ft. Lauderdale.\n            I want to read info from multiple sources, combine machine learning, and give the most likely answer.\n            \n            My selection is A, continue.', 'stream': False, 'options': {'temperature': 0.7, 'num_ctx': 1000, 'num_predict': 1000}}
# I'd be happy to help you create a product requirement for an AI bot that can provide information on traveling from Miami to Fort Lauderdale.
#
# Assumption #1: What type of device(s) would you like the AI bot to interact with?
#
# A) Mobile apps (e.g., iOS, Android)
# B) Voice assistants (e.g., Alexa, Google Assistant)
# C) Website or web application
# D) Physical kiosks
#
# Please select one of the options above.
# {'model': 'llama3.2:latest', 'prompt': '\n            Prompt #11\n            \n            Break this task into many different assumptions and compose the final answer based on my answers.\n            Ask me if additional follow up is needed after every assumption. Make sure "Assumption" is at the start of each assumption.\n            \n            Ensure there are 4 choices for each assumption - A, B, C, D. I will give an answer as the next prompt. \n            Increment the assumption count after each based on the prompt number.\n            \n            Give me product requirements to create an application to resolve on my travel for the situation: Create requirements for an AI bot that can give simple info on the best way to get from Miami to Ft. Lauderdale.\n            I want to read info from multiple sources, combine machine learning, and give the most likely answer.\n            \n            My selection is B, continue.', 'stream': False, 'options': {'temperature': 0.7, 'num_ctx': 1000, 'num_predict': 1000}}
# I'll guide you through breaking down this task into smaller assumptions.
#
# **Assumption #1**
# How would you like the AI bot to determine the best route for traveling from Miami to Ft. Lauderdale?
#
# A) By using a specific mapping algorithm
# B) By analyzing real-time traffic and road conditions
# C) By considering user preferences (e.g., fastest, most scenic, least expensive)
# D) By integrating with public transportation systems
#
# Please select one of the above options (A, B, C, or D).
# {'model': 'llama3.2:latest', 'prompt': '\n            Prompt #12\n            \n            Break this task into many different assumptions and compose the final answer based on my answers.\n            Ask me if additional follow up is needed after every assumption. Make sure "Assumption" is at the start of each assumption.\n            \n            Ensure there are 4 choices for each assumption - A, B, C, D. I will give an answer as the next prompt. \n            Increment the assumption count after each based on the prompt number.\n            \n            Give me product requirements to create an application to resolve on my travel for the situation: Create requirements for an AI bot that can give simple info on the best way to get from Miami to Ft. Lauderdale.\n            I want to read info from multiple sources, combine machine learning, and give the most likely answer.\n            \n            My selection is D, continue.', 'stream': False, 'options': {'temperature': 0.7, 'num_ctx': 1000, 'num_predict': 1000}}
# I'd be happy to help you create a product requirement for an AI bot that can assist with travel information.
#
# Assumption #1:
# Is your preferred mode of transportation when traveling between Miami and Ft. Lauderdale primarily by car, or would you also like the app to provide options for public transportation (e.g., buses, trains)?
#
# A) Primarily by car
# B) Public transportation only
# C) Both car and public transportation options
# D) Other (please specify)
#
# Please select one of the above options.
# {'model': 'llama3.2:latest', 'prompt': '\n            Prompt #13\n            \n            Break this task into many different assumptions and compose the final answer based on my answers.\n            Ask me if additional follow up is needed after every assumption. Make sure "Assumption" is at the start of each assumption.\n            \n            Ensure there are 4 choices for each assumption - A, B, C, D. I will give an answer as the next prompt. \n            Increment the assumption count after each based on the prompt number.\n            \n            Give me product requirements to create an application to resolve on my travel for the situation: Create requirements for an AI bot that can give simple info on the best way to get from Miami to Ft. Lauderdale.\n            I want to read info from multiple sources, combine machine learning, and give the most likely answer.\n            \n            My selection is D, continue.', 'stream': False, 'options': {'temperature': 0.7, 'num_ctx': 1000, 'num_predict': 1000}}
